# %%
import scipy.io as sio
import numpy as np
import pprint
pp = pprint.PrettyPrinter()

# %%
#use simplify_cells=True to get pretty print, should not affect the saved content

# %%
data_piv = sio.loadmat("piv/parameters/sample-parameters.mat",simplify_cells=True)
pp.pprint(data_piv)
# Out:
# {'__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Sun Jun  2 '
#                b'12:01:52 2024',
#  '__version__': '1.0',
#  'camera_design': {'diffraction_diameter': 3.0,
#                    'image_noise': 0.0,
#                    'implement_diffraction': 1,
#                    'intensity_rescaling': 1,
#                    'pixel_bit_depth': 8,
#                    'pixel_gain': 25.0,
#                    'pixel_pitch': 17,
#                    'x_camera_angle': -0.0,
#                    'x_pixel_number': 1024,
#                    'y_camera_angle': -0.0,
#                    'y_pixel_number': 1024},
#  'density_gradients': {'density_gradient_filename': '/home/xbao/LAB_test/shadow_piv_sim/photon/sample-data/piv/plume_1.nrrd',
#                        'gladstone_dale': 0.000225,
#                        'ray_tracing_algorithm': 2,
#                        'rho_0': 1.225,
#                        'simulate_density_gradients': 1},
# ...

# %%
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 1.0,#100
                 'focal_length': 60e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 1400e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 1.0,#100
                 'focal_length': 70e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 1700e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 2.0,#100
                 'focal_length': 90e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 2000e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 2.0,#100
                 'focal_length': 100e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 2400e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 8.0,#100
                 'focal_length': 105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 700000.0,
                 'ray_cone_pitch_ratio': 0.0001}#1

# %%
# for 22.5 cm^2 zone
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 2.0,#100
                 'focal_length': 98e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 1400e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
# for 22.5 cm^2 zone
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 4.0,#100
                 'focal_length': 95.5e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 1400e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
# for 22.5 cm^2 zone
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 4.0,#100
                 'focal_length': 171e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 2400e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
# for 22.5 cm^2 zone
# large object_distance and small focal length-> zoom out
data_piv['lens_design']={'aperture_f_number': 5.0,#100
                 'focal_length': 171e3,#105000.0,
                 'lens_model': 'general',
                 'lens_radius_of_curvature': 100000.0,
                 'object_distance': 2400e3,#700000.0,
                 'ray_cone_pitch_ratio': 1e-4}#1

# %%
data_piv['particle_field']['lightray_number_per_particle']=1e3#1e5

# %%
data_piv['particle_field']['frame_vector'] = np.array([1])

# %%
data_piv['particle_field']['frame_vector']
# Out:
# [1]

# %%
data_piv['particle_field']['particle_number']=5e4

# %%
data_piv['camera_design']['pixel_bit_depth']=8

# %%
data_piv['particle_field']['lightray_number_per_particle']=1000

# %%
data_piv['particle_field']['perform_mie_scattering']=0

# %%
data_piv['particle_field']['load_particle_data'] = 1
data_piv['particle_field']['data_directory'] = "../sample-data/piv/"
data_piv['particle_field']['particle_number']=len(X)

# %%
data_piv['density_gradients']["density_gradient_filename"] = "/home/xbao/LAB_test/shadow_piv_sim/photon/sample-data/piv/plume_1.nrrd"

# %%
for i in np.array(data_piv['particle_field']['frame_vector']):
    print(i)
# Out:
# 1

# %%
np.array([X,Y])
# Out:
# array([[  9235.02873934,  25366.43929373, -19194.37648246, ...,
#          17672.64353749,  17682.78667728,  17690.4189105 ],
#        [ 23539.90476381,  13500.75958297,  10771.71105822, ...,
#          13100.46464132,  13111.21341893,  13095.73742909]])

# %%
data_piv['particle_field']['frame_vector'] = np.array([1,2])

# %%
data_piv['particle_field']['beam_propogation_vector'] = np.array([1.0, 0.0, 0.0])

# %%
data_piv['particle_field']['lightray_number_per_particle']=1000

# %%
sio.savemat("piv/parameters/sample-parameters.mat",data_piv, appendmat=True, format='5', long_field_names=True)

# %%
def generate_large_points(X,Y,Z,pt_per_tracer=10,interval=4,tracer_radius_max=600,tracer_radius_min=300):
    # for every 10th point, generate a series of overlapping points around it
    # first create a template with radius and angle
#     pt_per_tracer = 10
#     interval = 4
#     tracer_radius_max = 600
#     tracer_radius_min = 300
    np.random.seed()
    radii_unit = np.random.rand(pt_per_tracer)
    thetas_single = 2 * np.pi * np.random.rand(pt_per_tracer)
    X_sub,Y_sub,Z_sub = X[::interval], Y[::interval], Z[::interval]
    radius_scaling = np.random.rand(len(X_sub)) * (tracer_radius_max - tracer_radius_min) + tracer_radius_min

    radii = np.repeat(radius_scaling ,pt_per_tracer) * np.tile(radii_unit ,len(X_sub))
    thetas = np.tile(thetas_single ,len(X_sub))
    X_add = radii * np.cos(thetas) + np.repeat(X_sub,pt_per_tracer)
    Y_add = radii * np.sin(thetas) + np.repeat(Y_sub,pt_per_tracer)
    Z_add = np.repeat(Z_sub,pt_per_tracer)
    X = np.concatenate((X,X_add))
    Y = np.concatenate((Y,Y_add))
    Z = np.concatenate((Z,Z_add))
    return X,Y,Z
X_Min,X_Max,Y_Min,Y_Max,Z_Min,Z_Max = -11.25e4, 11.25e4,-11.25e4, 11.25e4,-2.5e4, 2.5e4
np.random.seed()
particle_number=int(3e4)
X = (X_Max - X_Min) * np.random.rand(particle_number) + X_Min
Y = (Y_Max - Y_Min) * np.random.rand(particle_number) + Y_Min
Z = (Z_Max - Z_Min) * np.random.rand(particle_number) + Z_Min

cutoff = particle_number//2

# X1,Y1,Z1 = generate_large_points(X[:cutoff],Y[:cutoff],Z[:cutoff],pt_per_tracer=7,interval=1,tracer_radius_max=40,tracer_radius_min=20)
# X2,Y2,Z2 = generate_large_points(X[1::3],Y[1::3],Z[1::3],pt_per_tracer=55,interval=1,tracer_radius_max=1000,tracer_radius_min=800)

# head_particle_number = int(3e2)
# #generate pts at the edge of the head
# x_c,y_c = 0, -1.7e4
# a_head = 2.4e4
# b_head = 2.8e4
# R_scatter = 1e4
# np.random.seed()
# radii_a = a_head + np.random.rand(head_particle_number)*R_scatter
# radii_b = b_head + np.random.rand(head_particle_number)*R_scatter
# thetas = np.pi * np.random.rand(head_particle_number)
# X_head = radii_a * np.cos(thetas)
# Y_head = radii_b * np.sin(thetas) + y_c
# Z_head = (Z_Max - Z_Min) * np.random.rand(head_particle_number) + Z_Min

# X1,Y1,Z1 = generate_large_points(X_head,Y_head,Z_head,pt_per_tracer=80,interval=1,tracer_radius_max=900,tracer_radius_min=200)
X1,Y1,Z1 = generate_large_points(X[:cutoff],Y[:cutoff],Z[:cutoff],pt_per_tracer=30,interval=1,tracer_radius_max=900,tracer_radius_min=200)
X2,Y2,Z2 = generate_large_points(X[cutoff:],Y[cutoff:],Z[cutoff:],pt_per_tracer=60,interval=1,tracer_radius_max=900,tracer_radius_min=200)

# Radii_2_inner = ((X2-x_c)/a_head)**2 + ((Y2-y_c)/b_head)**2
# Radii_2_outer = ((X2-x_c)/(a_head+R_scatter))**2 + ((Y2-y_c)/(b_head+R_scatter))**2
# overlap_flag = np.invert(np.array((Radii_2_inner>=1.01)&(Radii_2_outer<=0.95)&(Y2>y_c)))

# X,Y,Z = X2,Y2,Z2
X = np.concatenate((X1,X2))
Y = np.concatenate((Y1,Y2))
Z = np.concatenate((Z1,Z2))
# import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
plt.scatter(X,Y,s=0.1)

# %%
particle_mat = dict()
particle_mat['X']=X
particle_mat['Y']=Y
particle_mat['Z']=Z

# %%
sio.savemat("piv/particle_data_frame_1.mat",particle_mat, appendmat=True, format='5', long_field_names=True)

# %% [markdown]
# # testing object_distance and z_object

# %%
simulation_parameters = data.copy()

# %%
import sys
sys.path.append('../python_codes')

# %%
from run_simulation_02 import create_camera_optical_system

# %%
optical_system = create_camera_optical_system(simulation_parameters)
# Out:
# n: 1.8336, t: 140.67, R: 100000.00

# %%
# % This extracts the object distance of the lens (ie the distance between
# % the lens front principal plane and the center of the focal plane) to the
# % design structure (in microns)
object_distance = simulation_parameters['lens_design']['object_distance']
# % This extracts the lens focal length from the design structure (in microns)
focal_length = simulation_parameters['lens_design']['focal_length']

# % This extracts the grid point diameter from the structure
grid_point_diameter = simulation_parameters['bos_pattern']['grid_point_diameter']
# % This extracts the grid point number from the calibration structure
grid_point_number = int(simulation_parameters['bos_pattern']['grid_point_number'])
# % This extracts the number of light source partciles per grid point from
# % the calibration structure
particle_number_per_grid_point = simulation_parameters['bos_pattern']['particle_number_per_grid_point']

# % This extracts the x angle of the camera to the particle volume
x_camera_angle = simulation_parameters['camera_design']['x_camera_angle']
# % This extracts the y angle of the camera to the particle volume
y_camera_angle = simulation_parameters['camera_design']['y_camera_angle']

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % Extracts parameters from 'optical_system'                               %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# % This extracts the lens refractive index
refractive_index = optical_system['design']['optical_element'][0]['optical_element'][0]['element_properties']['refractive_index']
# % This extracts the radius of curvature for the front surface of the lens
front_surface_radius=optical_system['design']['optical_element'][0]['optical_element'][0]['element_geometry']['front_surface_radius']
# % This extracts the radius of curvature for the back surface of the lens
back_surface_radius=optical_system['design']['optical_element'][0]['optical_element'][0]['element_geometry']['back_surface_radius']
# % This extracts the front surface to back surface vertex distance of the
# % lens
optical_system_length=optical_system['design']['optical_element'][0]['optical_element'][0]['element_geometry']['vertex_distance']

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % Calculates optical system properties                                    %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# % This calculates the image distance
image_distance = (1.0/focal_length - 1.0/object_distance)**-1 #+ 444.4410

# % This calculates the offsets of the principal planes
h1_principal_plane = -(focal_length * (refractive_index - 1.0) * optical_system_length)/(back_surface_radius * refractive_index)
h2_principal_plane = -(focal_length * (refractive_index - 1.0) * optical_system_length)/(front_surface_radius * refractive_index)

# % This calculates the positions of the lens vertex planes
v2_vertex_plane = image_distance + h2_principal_plane
v1_vertex_plane = v2_vertex_plane + optical_system_length

# % This is the object distance of the lens
z_object = v1_vertex_plane - h1_principal_plane + object_distance

# %%
object_distance
# Out:
# 700000.0

# %%
z_object
# Out:
# 823668.3478484906

# %%
z_offset = z_object-object_distance 
print(z_offset)
# Out:
# 123668.34784849058

# %%
# % This extracts the object distance of the lens (ie the distance between
# % the lens front principal plane and the center of the focal plane) to the
# % design structure (in microns)
object_distance = simulation_parameters['lens_design']['object_distance']
# % This extracts the lens focal length from the design structure (in microns)
focal_length = simulation_parameters['lens_design']['focal_length']

# % This extracts the grid point diameter from the structure
grid_point_diameter = simulation_parameters['bos_pattern']['grid_point_diameter']
# % This extracts the grid point number from the calibration structure
grid_point_number = int(simulation_parameters['bos_pattern']['grid_point_number'])
# % This extracts the number of light source partciles per grid point from
# % the calibration structure
particle_number_per_grid_point = simulation_parameters['bos_pattern']['particle_number_per_grid_point']

# % This extracts the x angle of the camera to the particle volume
x_camera_angle = simulation_parameters['camera_design']['x_camera_angle']
# % This extracts the y angle of the camera to the particle volume
y_camera_angle = simulation_parameters['camera_design']['y_camera_angle']

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % Extracts parameters from 'optical_system'                               %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# % This extracts the lens refractive index
refractive_index = optical_system['design']['optical_element'][0]['optical_element'][0]['element_properties']['refractive_index']
# % This extracts the radius of curvature for the front surface of the lens
front_surface_radius=optical_system['design']['optical_element'][0]['optical_element'][0]['element_geometry']['front_surface_radius']
# % This extracts the radius of curvature for the back surface of the lens
back_surface_radius=optical_system['design']['optical_element'][0]['optical_element'][0]['element_geometry']['back_surface_radius']
# % This extracts the front surface to back surface vertex distance of the
# % lens
optical_system_length=optical_system['design']['optical_element'][0]['optical_element'][0]['element_geometry']['vertex_distance']

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % Calculates optical system properties                                    %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# % This calculates the image distance
image_distance = (1.0/focal_length - 1.0/object_distance)**-1 #+ 444.4410

# % This calculates the offsets of the principal planes
h1_principal_plane = -(focal_length * (refractive_index - 1.0) * optical_system_length)/(back_surface_radius * refractive_index)
h2_principal_plane = -(focal_length * (refractive_index - 1.0) * optical_system_length)/(front_surface_radius * refractive_index)

# % This calculates the positions of the lens vertex planes
v2_vertex_plane = image_distance + h2_principal_plane
v1_vertex_plane = v2_vertex_plane + optical_system_length

# % This is the object distance of the lens
z_object = v1_vertex_plane - h1_principal_plane + object_distance

# %%
z_object
# Out:
# 1462750.4967207052

# %%
823668-750e3-z_offset
# Out:
# -50000.34784849058

# %%
np.array([True,False],dtype=int)
# Out:
# array([1, 0])

# %% [markdown]
# # syrup n change

# %%
#refractive index n for syrup
T=25
-2.058*1e-4*T +1.5012
# Out:
# 1.4960550000000001

# %%
def n_syrup(T):
    return -2.058*1e-4*T +1.5012

# %%
#refractive index n for syrup
T=50
-2.058*1e-4*T +1.5012
# Out:
# 1.4909100000000002

# %%
(n_syrup(25)-n_syrup(50))/n_syrup(25)
# Out:
# 0.003439044687528169

# %%
(n_syrup(25)-n_syrup(50))/n_syrup(25)

# %%
0.003/(1e4/100/1e3)
# Out:
# 0.03

# %%
#density of syrup ρ
-5.875*1e-4*T +1.442
# Out:
# 1.4273125

# %%
2.058/5.875
# Out:
# 0.3502978723404255

# %%
#T = (rho -1.442)/(-5.875*1e-4) 
# n = -2.058*1e-4*T +1.5012 = 2.058*1e-4*(rho -1.442)/(5.875*1e-4) + 0.5012 + 1
# n =  2.058*(rho -1.442)/5.875 + 0.5012 + 1 = 0.3503*(rho -1.442) + 0.5012 + 1

# %%
# !pwd
# Out:
# /home/xbao/LAB_test/shadow_piv_sim/photon/sample-data
